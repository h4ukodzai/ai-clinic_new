# %%
from PIL import Image

try:
    img = Image.open("assets/ai_doctor_hero3.jpg")
    img.show()
    print("Image is valid!")
except Exception as e:
    print("Invalid image:", e)
# Out:
# Invalid image: [Errno 2] No such file or directory: 'assets/ai_doctor_hero3.jpg'
